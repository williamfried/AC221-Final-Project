# %%
from collections import defaultdict, Counter
import matplotlib.pyplot as plt
import multiprocessing as mp
import numpy as np
import pandas as pd
import sys
import time
from scipy.stats import entropy
from math import log, e
from scipy.stats.stats import pearsonr  


from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.utils import resample
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from skopt import BayesSearchCV

plt.rc('axes', titlesize=20) 
plt.rc('axes', labelsize=15)
plt.rc('legend', fontsize=20)

# %% [markdown]
# ## Load the data

# %%
data_raw = pd.read_csv('AP221Harvardx.csv')
# Out:
# /Users/dvamvou/anaconda3/envs/ds/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (4,27,28,45,46,47,48,49,55,56,59,60,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_raw.head(5)
# Out:
#                   course_id  user_id  registered  viewed explored  certified  \
# 0  HarvardX/PH525.1x/1T2018   814784        True    True    False      False
# 1  HarvardX/PH525.1x/1T2018  7945078        True   False      NaN      False
# 2  HarvardX/PH525.1x/1T2018  5465534        True    True    False      False
# 3  HarvardX/PH525.1x/1T2018  8087152        True    True    False      False
# 4  HarvardX/PH525.1x/1T2018  5032030        True   False      NaN      False
#
#    completed              ip cc_by_ip   countryLabel  ... roles_isInstructor  \
# 0      False    74.12.190.49       CA         Canada  ...                NaN
# 1      False     60.10.17.72       CN          China  ...                NaN
# 2      False  109.196.85.139       PL         Poland  ...                NaN
# 3      False  203.110.242.10       IN          India  ...                NaN
# 4      False   96.82.226.121       US  United States  ...                NaN
#
#   roles_isStaff roles_isCCX roles_isFinance roles_isLibrary roles_isSales  \
# 0           NaN         NaN             NaN             NaN           NaN
# 1           NaN         NaN             NaN             NaN           NaN
# 2           NaN         NaN             NaN             NaN           NaN
# 3           NaN         NaN             NaN             NaN           NaN
# 4           NaN         NaN             NaN             NaN           NaN
#
#   forumRoles_isAdmin forumRoles_isCommunityTA forumRoles_isModerator  \
# 0                NaN                      NaN                    NaN
# 1                NaN                      NaN                    NaN
# 2                NaN                      NaN                    NaN
# 3                NaN                      NaN                    NaN
# 4                NaN                      NaN                    NaN
#
#    forumRoles_isStudent
# 0                   1.0
# 1                   1.0
# 2                   1.0
# 3                   1.0
# 4                   1.0
#
# [5 rows x 91 columns]

# %%
data_raw.shape
# Out:
# (6860993, 91)

# %% [markdown]
# ## Create a sub-dataset with some of the quasi-identifiers plus the grade

# %%
quasi_identifiers = 'course_id YoB countryLabel LoE gender nforum_posts'.split()
non_qi_fields = ['grade']
df = data_raw[quasi_identifiers + non_qi_fields]

# %%
df.shape
# Out:
# (6860993, 7)

# %%
df.head()
# Out:
#                   course_id  YoB   countryLabel  LoE gender  nforum_posts  \
# 0  HarvardX/PH525.1x/1T2018  NaN         Canada  NaN    NaN           NaN
# 1  HarvardX/PH525.1x/1T2018  NaN          China  NaN    NaN           NaN
# 2  HarvardX/PH525.1x/1T2018  NaN         Poland  NaN    NaN           NaN
# 3  HarvardX/PH525.1x/1T2018  NaN          India  NaN    NaN           NaN
# 4  HarvardX/PH525.1x/1T2018  NaN  United States  NaN    NaN           NaN
#
#    grade
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
filename = 'partial_dataset.csv'

# %%
df.to_csv(filename, index=False)

# %%
df_original = pd.read_csv(filename)

# %%
df_original.head()
# Out:
#                   course_id  YoB   countryLabel  LoE gender  nforum_posts  \
# 0  HarvardX/PH525.1x/1T2018  NaN         Canada  NaN    NaN           NaN
# 1  HarvardX/PH525.1x/1T2018  NaN          China  NaN    NaN           NaN
# 2  HarvardX/PH525.1x/1T2018  NaN         Poland  NaN    NaN           NaN
# 3  HarvardX/PH525.1x/1T2018  NaN          India  NaN    NaN           NaN
# 4  HarvardX/PH525.1x/1T2018  NaN  United States  NaN    NaN           NaN
#
#    grade
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df_original.isna().sum()
# Out:
# course_id             0
# YoB             1049890
# countryLabel    1109868
# LoE              998390
# gender           914661
# nforum_posts    6623522
# grade           1930278
# dtype: int64

# %%
df_original['countryLabel'].value_counts(normalize=True).shape
# Out:
# (254,)

# %%
df_original['countryLabel'].value_counts(normalize=True)
# Out:
# United States                     3.215562e-01
# India                             8.051659e-02
# United Kingdom                    4.258541e-02
# Brazil                            3.990889e-02
# Canada                            3.853490e-02
# China                             2.717399e-02
# Australia                         2.169854e-02
# Germany                           1.940664e-02
# Mexico                            1.914512e-02
# Spain                             1.716203e-02
# France                            1.580039e-02
# Colombia                          1.241183e-02
# Netherlands                       1.128040e-02
# Russian Federation                1.075685e-02
# Turkey                            1.074868e-02
# Pakistan                          9.995262e-03
# Egypt                             9.821209e-03
# Greece                            9.424069e-03
# Philippines                       9.339042e-03
# Japan                             9.081354e-03
# Nigeria                           9.007107e-03
# Singapore                         8.985720e-03
# Italy                             8.467387e-03
# Indonesia                         8.152840e-03
# Poland                            8.085375e-03
# Hong Kong                         8.037384e-03
# Ukraine                           7.464279e-03
# Taiwan                            7.045056e-03
# Peru                              6.701819e-03
# Argentina                         6.305027e-03
#                                       ...
# Bonaire                           7.824556e-06
# Central African Republic          6.607403e-06
# Mayotte                           5.738008e-06
# Aland Islands                     5.564129e-06
# Guinea-Bissau                     5.216371e-06
# Kiribati                          4.520855e-06
# Sint Maarten                      4.173097e-06
# Comoros                           3.477580e-06
# Timor-Leste                       3.129822e-06
# Palau                             2.955943e-06
# São Tomé and Príncipe             2.782064e-06
# Montserrat                        2.608185e-06
# British Virgin Islands            2.260427e-06
# Brunei                            2.086548e-06
# Cook Islands                      1.912669e-06
# San Marino                        1.564911e-06
# Antarctica                        1.564911e-06
# Sint Maarten (Dutch part)         1.043274e-06
# Tuvalu                            8.693951e-07
# Vatican City                      8.693951e-07
# North Korea                       8.693951e-07
# Falkland Islands (Malvinas)       6.955161e-07
# Nauru                             5.216371e-07
# Saint Martin (French part)        5.216371e-07
# Niue                              5.216371e-07
# Saint Helena                      5.216371e-07
# Saint Pierre and Miquelon         3.477580e-07
# Åland                             1.738790e-07
# Falkland Islands                  1.738790e-07
# British Indian Ocean Territory    1.738790e-07
# Name: countryLabel, Length: 254, dtype: float64

# %% [markdown]
# ## Data cleaning - set nforum_posts which are NaN to 0

# %%
df_original_cleaned = df_original.copy(deep=True)

# %%
df_original_cleaned.loc[df_original_cleaned['nforum_posts'].isna(), 'nforum_posts'] = 0

# %%
df_original_cleaned.isna().sum()
# Out:
# course_id             0
# YoB             1049890
# countryLabel    1109868
# LoE              998390
# gender           914661
# nforum_posts          0
# grade           1930278
# dtype: int64

# %%
df_original_cleaned.describe()
# Out:
#                 YoB  nforum_posts         grade
# count  5.811103e+06  6.860993e+06  4.930715e+06
# mean   1.984321e+03  2.458084e-01  4.063551e-02
# std    1.234031e+01  3.767435e+00  1.656013e-01
# min    5.130000e+02  0.000000e+00 -5.000000e-02
# 25%    1.979000e+03  0.000000e+00  0.000000e+00
# 50%    1.988000e+03  0.000000e+00  0.000000e+00
# 75%    1.993000e+03  0.000000e+00  0.000000e+00
# max    3.116000e+03  3.770000e+03  1.200000e+00

# %% [markdown]
# Calculate the original correlation between `nforum_posts` and `grade`.

# %%
df_original_corr = df_original_cleaned['nforum_posts'].corr(df_original_cleaned['grade'], method='pearson')
df_original_corr
# Out:
# 0.2699651746572297

# %% [markdown]
# ## Load data with synthetic rows

# %%
synthetic_df = pd.read_csv('synthetic_dataset_supersets.csv')

# %%
synthetic_df.head()
# Out:
#    Unnamed: 0                 course_id  YoB   countryLabel  LoE gender  \
# 0           0  HarvardX/PH525.1x/1T2018  NaN         Canada  NaN    NaN
# 1           1  HarvardX/PH525.1x/1T2018  NaN          China  NaN    NaN
# 2           2  HarvardX/PH525.1x/1T2018  NaN         Poland  NaN    NaN
# 3           3  HarvardX/PH525.1x/1T2018  NaN          India  NaN    NaN
# 4           4  HarvardX/PH525.1x/1T2018  NaN  United States  NaN    NaN
#
#    nforum_posts  grade
# 0           0.0    NaN
# 1           0.0    NaN
# 2           0.0    NaN
# 3           0.0    NaN
# 4           0.0    NaN

# %%
synthetic_df.shape
# Out:
# (12180246, 8)

# %%
synthetic_df.isna().sum()
# Out:
# Unnamed: 0            0
# course_id             0
# YoB             1087585
# countryLabel    1146438
# LoE             1077012
# gender           952979
# nforum_posts          0
# grade           1930278
# dtype: int64

# %%
grade_marginal_distribution = synthetic_df[(synthetic_df['grade'].notnull()) & (synthetic_df['grade'] != 9999.0)]['grade'].values

# %%
df_original.loc[df_original['grade'].notnull()].shape
# Out:
# (4930715, 7)

# %%
synthetic_df.loc[(synthetic_df['grade']!=9999)&(synthetic_df['grade'].notnull())].shape
# Out:
# (4930715, 12)

# %% [markdown]
# ## Sample grade from the marginal distribution

# %%
samples_from_marginal_grade_dist = np.random.choice(grade_marginal_distribution, size = synthetic_df[synthetic_df['grade']==9999].shape[0], \
                 replace = True)
synthetic_df['grade_impute_marginal'] = synthetic_df['grade']
synthetic_df.loc[synthetic_df['grade_impute_marginal']==9999.0, 'grade_impute_marginal'] = samples_from_marginal_grade_dist

# %%
corr_bias = df_original_corr - synthetic_df['grade_impute_marginal'].corr(synthetic_df['nforum_posts'], method='pearson')

# %%
marginal_mean_bias = df_original_cleaned['grade'].mean() - synthetic_df['grade_impute_marginal'].mean()
print(f'Bias in mean grade for imputation with random sample from marginal is {marginal_mean_bias}')
print(f'Bias in correlation between grade and nforum_posts for imputation with random sample from marginal is {corr_bias}')
# Out:
# Bias in mean grade for imputation with random sample from marginal is 2.300478505520842e-05
# Bias in correlation between grade and nforum_posts for imputation with random sample from marginal is 0.18596957483374393

# %% [markdown]
# ## Average multiple samples from the marginal distribution to get grade

# %%
def average_samples_from_marginal(x):
    samples = np.random.choice(grade_marginal_distribution, size = 5, replace = True)
    return samples.mean()

# %%
synthetic_df['grade_impute_marginal_mean'] = synthetic_df['grade']
synthetic_df.loc[synthetic_df['grade_impute_marginal_mean']==9999.0, 'grade_impute_marginal_mean'] = \
synthetic_df.loc[synthetic_df['grade_impute_marginal_mean']==9999.0, 'grade_impute_marginal_mean'].apply(average_samples_from_marginal)

# %%
corr_bias = df_original_corr - synthetic_df['grade_impute_marginal_mean'].corr(synthetic_df['nforum_posts'], method='pearson')
marginal_mean_bias = df_original_cleaned['grade'].mean() - synthetic_df['grade_impute_marginal_mean'].mean()
print(f'Bias in mean grade for imputation with random sample from marginal is {marginal_mean_bias}')
print(f'Bias in correlation between grade and nforum_posts for imputation with random sample from marginal is {corr_bias}')
# Out:
# Bias in mean grade for imputation with random sample from marginal is -1.0785173819326255e-05
# Bias in correlation between grade and nforum_posts for imputation with random sample from marginal is 0.16001774574717303

# %% [markdown]
# ## Tree-based algorithms to fill in the missing values of the grades

# %%
#code to encode labels for multiple categorical predictors

from sklearn.preprocessing import LabelEncoder

class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
def calc_meanstd(X_train, y_train, depths, folds, scoring):
    cvmeans = []
    train_scores = []
    cvstds = []
    for depth in depths:
        dt = tree.DecisionTreeRegressor(max_depth=depth)
        cv_scores = cross_val_score(dt, X_train, y_train, cv=folds, scoring=scoring)
        cvmeans.append(cv_scores.mean())
        cvstds.append(cv_scores.std())
        dt.fit(X_train, y_train)
        train_scores.append(dt.score(X_train, y_train))
    cvmeans = np.array(cvmeans)
    cvstds = np.array(cvstds)
    return cvmeans, cvstds

# %% [markdown]
# ## How to handle missing values?
#
# For categorical predictors, we encode `NaN` as another category. For `YoB`, we filled any missing values with the median year of birth. We also changed the `countryLabel` column to a binary one to encode whether the country is US (1) or not (0), thus reducing the number of possible categories that the column can take.

# %%
df_filled = df_original_cleaned.copy(deep=True)
df_filled[['countryLabel', 'LoE', 'gender']] = df_filled[['countryLabel', 'LoE', 'gender']].fillna('Null')

# %%
df_filled['countryLabel_bin'] = 0
df_filled.loc[df_filled['countryLabel']=='United States', 'countryLabel_bin'] = 1
df_filled.head()
# Out:
#                   course_id  YoB   countryLabel   LoE gender  nforum_posts  \
# 0  HarvardX/PH525.1x/1T2018  NaN         Canada  Null   Null           0.0
# 1  HarvardX/PH525.1x/1T2018  NaN          China  Null   Null           0.0
# 2  HarvardX/PH525.1x/1T2018  NaN         Poland  Null   Null           0.0
# 3  HarvardX/PH525.1x/1T2018  NaN          India  Null   Null           0.0
# 4  HarvardX/PH525.1x/1T2018  NaN  United States  Null   Null           0.0
#
#    grade  countryLabel_bin
# 0    NaN                 0
# 1    NaN                 0
# 2    NaN                 0
# 3    NaN                 0
# 4    NaN                 1

# %%
df_filled['YoB'] = df_filled['YoB'].fillna(df_filled['YoB'].median())
df_filled.head()
# Out:
#                   course_id     YoB   countryLabel   LoE gender  nforum_posts  \
# 0  HarvardX/PH525.1x/1T2018  1988.0         Canada  Null   Null           0.0
# 1  HarvardX/PH525.1x/1T2018  1988.0          China  Null   Null           0.0
# 2  HarvardX/PH525.1x/1T2018  1988.0         Poland  Null   Null           0.0
# 3  HarvardX/PH525.1x/1T2018  1988.0          India  Null   Null           0.0
# 4  HarvardX/PH525.1x/1T2018  1988.0  United States  Null   Null           0.0
#
#    grade  countryLabel_bin
# 0    NaN                 0
# 1    NaN                 0
# 2    NaN                 0
# 3    NaN                 0
# 4    NaN                 1

# %%
multi_label_enc = MultiColumnLabelEncoder(columns = ['course_id','LoE','gender'])

# %%
df_filled_encoded = multi_label_enc.fit_transform(df_filled)
df_filled_encoded.head()
# Out:
#    course_id     YoB   countryLabel  LoE  gender  nforum_posts  grade  \
# 0        166  1988.0         Canada    1       0           0.0    NaN
# 1        166  1988.0          China    1       0           0.0    NaN
# 2        166  1988.0         Poland    1       0           0.0    NaN
# 3        166  1988.0          India    1       0           0.0    NaN
# 4        166  1988.0  United States    1       0           0.0    NaN
#
#    countryLabel_bin
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 1

# %%
df_encoded_grade_not_null = df_filled_encoded.loc[df_filled_encoded['grade'].notnull()]
X = df_encoded_grade_not_null[['course_id', 'YoB', 'LoE', 'gender', 'nforum_posts','countryLabel_bin']].values
y = df_encoded_grade_not_null['grade'].values

# %%
print(X.shape)
print(y.shape)
# Out:
# (4930715, 6)
# (4930715,)

# %%
depths = np.arange(10,100,10)
cvmeans, cvstds = calc_meanstd(X, y, depths, folds=3, scoring='r2')

# %%
cvmeans
# Out:
# array([-0.70619219, -2.6001578 , -2.827799  , -2.82755096, -2.82567621,
#        -2.82292562, -2.83235772, -2.83166247, -2.82155569])

# %%
depths = np.arange(10,40,5)
cvmeans_rmse, cvstds_rmse = calc_meanstd(X, y, depths, folds=3, scoring='neg_mean_squared_error')

# %%
cvmeans_rmse
# Out:
# array([-0.06075985, -0.10365384, -0.11447625, -0.11962043, -0.1200914 ,
#        -0.12019464])

# %%
dt_10 = tree.DecisionTreeRegressor(max_depth=10)
dt_10.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=10, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %% [markdown]
# ## Imputation with Decision Tree predicted grade

# %%
synthetic_df.loc[synthetic_df['grade']==9999.0]
# Out:
#           Unnamed: 0                   course_id     YoB    countryLabel LoE  \
# 6860993            0     HarvardX/ER22.1x/2015T3  1977.0           Haiti  hs
# 6860994            1     HarvardX/ER22.1x/2015T3  1977.0           Haiti  hs
# 6860995            2     HarvardX/ER22.1x/2015T3  1977.0           Haiti  hs
# 6860996            3     HarvardX/ER22.1x/2015T3  1977.0           Haiti  hs
# 6860997            4        HarvardX/CS50x3/2015  1996.0           China   m
# 6860998            5        HarvardX/CS50x3/2015  1996.0           China   m
# 6860999            6        HarvardX/CS50x3/2015  1996.0           China   m
# 6861000            7        HarvardX/CS50x3/2015  1996.0           China   m
# 6861001            8     HarvardX/1368.4x/2T2015  1997.0        Pakistan  hs
# 6861002            9     HarvardX/1368.4x/2T2015  1997.0        Pakistan  hs
# 6861003           10     HarvardX/1368.4x/2T2015  1997.0        Pakistan  hs
# 6861004           11     HarvardX/1368.4x/2T2015  1997.0        Pakistan  hs
# 6861005           12       HarvardX/GSE3x/1T2015  1994.0   United States   b
# 6861006           13       HarvardX/GSE3x/1T2015  1994.0   United States   b
# 6861007           14       HarvardX/GSE3x/1T2015  1994.0   United States   b
# 6861008           15       HarvardX/PH556/2015T3  1972.0     Switzerland   m
# 6861009           16       HarvardX/PH556/2015T3  1972.0     Switzerland   m
# 6861010           17       HarvardX/PH556/2015T3  1972.0     Switzerland   m
# 6861011           18       HarvardX/PH556/2015T3  1972.0     Switzerland   m
# 6861012           19       HarvardX/SW12.1x/2016  1995.0          France   m
# 6861013           20       HarvardX/SW12.1x/2016  1995.0          France   m
# 6861014           21       HarvardX/SW12.1x/2016  1995.0          France   m
# 6861015           22       HarvardX/SW12.1x/2016  1995.0          France   m
# 6861016           23             HarvardX/CS50/X  1975.0     Philippines   m
# 6861017           24             HarvardX/CS50/X  1975.0     Philippines   m
# 6861018           25             HarvardX/CS50/X  1975.0     Philippines   m
# 6861019           26             HarvardX/CS50/X  1975.0     Philippines   m
# 6861020           27    HarvardX/PH525.1x/1T2015  1984.0           Korea   b
# 6861021           28    HarvardX/PH525.1x/1T2015  1984.0           Korea   b
# 6861022           29    HarvardX/PH525.1x/1T2015  1984.0           Korea   b
# ...              ...                         ...     ...             ...  ..
# 12180216     5319223       HarvardX/HLS4X/1T2017  1993.0          Canada   b
# 12180217     5319224       HarvardX/HLS4X/1T2017  1993.0          Canada   b
# 12180218     5319225       HarvardX/HLS4X/1T2017  1993.0          Canada   b
# 12180219     5319226      HarvardX/PH526x/3T2016  1997.0           Egypt  hs
# 12180220     5319227      HarvardX/PH526x/3T2016  1997.0           Egypt  hs
# 12180221     5319228      HarvardX/PH526x/3T2016  1997.0           Egypt  hs
# 12180222     5319229    HarvardX/SPU27.2x/2T2017  1980.0          Cyprus   m
# 12180223     5319230    HarvardX/SPU27.2x/2T2017  1980.0          Cyprus   m
# 12180224     5319231    HarvardX/SPU27.2x/2T2017  1980.0          Cyprus   m
# 12180225     5319232    HarvardX/SPU27.2x/2T2017  1980.0          Cyprus   m
# 12180226     5319233     HarvardX/SPU27x/2015_Q2  1979.0        Botswana   b
# 12180227     5319234     HarvardX/SPU27x/2015_Q2  1979.0        Botswana   b
# 12180228     5319235     HarvardX/SPU27x/2015_Q2  1979.0        Botswana   b
# 12180229     5319236     HarvardX/SPU27x/2015_Q2  1979.0        Botswana   b
# 12180230     5319237    HarvardX/PH125.1x/2T2017  1994.0         Ukraine   m
# 12180231     5319238    HarvardX/PH125.1x/2T2017  1994.0         Ukraine   m
# 12180232     5319239    HarvardX/PH125.1x/2T2017  1994.0         Ukraine   m
# 12180233     5319240    HarvardX/PH125.1x/2T2017  1994.0         Ukraine   m
# 12180234     5319241            HarvardX/CS50/AP  1997.0           Italy  hs
# 12180235     5319242            HarvardX/CS50/AP  1997.0           Italy  hs
# 12180236     5319243            HarvardX/CS50/AP  1997.0           Italy  hs
# 12180237     5319244            HarvardX/CS50/AP  1997.0           Italy  hs
# 12180238     5319245     HarvardX/1368.4x/2T2016  1969.0   United States   m
# 12180239     5319246     HarvardX/1368.4x/2T2016  1969.0   United States   m
# 12180240     5319247      HarvardX/PH231x/1T2017  1978.0  United Kingdom   m
# 12180241     5319248      HarvardX/PH231x/1T2017  1978.0  United Kingdom   m
# 12180242     5319249      HarvardX/PH231x/1T2017  1978.0  United Kingdom   m
# 12180243     5319250  HarvardX/HDS3221.5x/2T2016  1989.0       Australia  hs
# 12180244     5319251  HarvardX/HDS3221.5x/2T2016  1989.0       Australia  hs
# 12180245     5319252  HarvardX/HDS3221.5x/2T2016  1989.0       Australia  hs
#
#          gender  nforum_posts   grade  grade_dt10_pred  grade_rf_pred  \
# 6860993       f           0.0  9999.0         0.020885       0.032812
# 6860994       f           0.0  9999.0         0.034760       0.032812
# 6860995       f           0.0  9999.0         0.043970       0.032812
# 6860996       f           0.0  9999.0         0.076576       0.032812
# 6860997       m           0.0  9999.0        -0.011029       0.000004
# 6860998       m           0.0  9999.0        -0.028877       0.000004
# 6860999       m           0.0  9999.0        -0.007106       0.000004
# 6861000       m           0.0  9999.0         0.010213       0.000004
# 6861001       f           0.0  9999.0         0.065591       0.035069
# 6861002       f           0.0  9999.0         0.054299       0.035069
# 6861003       f           0.0  9999.0         0.058716       0.035069
# 6861004       f           0.0  9999.0         0.070454       0.035069
# 6861005       m           0.0  9999.0         0.049190       0.033995
# 6861006       m           0.0  9999.0         0.054237       0.033995
# 6861007       m           0.0  9999.0         0.132388       0.033995
# 6861008       m           0.0  9999.0         0.032087       0.039694
# 6861009       m           0.0  9999.0         0.038834       0.039694
# 6861010       m           0.0  9999.0         0.019795       0.039694
# 6861011       m           0.0  9999.0         0.045101       0.039694
# 6861012       m           0.0  9999.0         0.054886       0.026575
# 6861013       m           0.0  9999.0         0.045999       0.026575
# 6861014       m           0.0  9999.0        -0.015491       0.026575
# 6861015       m           0.0  9999.0         0.024039       0.026575
# 6861016       o           0.0  9999.0         0.013597       0.000008
# 6861017       o           0.0  9999.0        -0.006108       0.000008
# 6861018       o           0.0  9999.0        -0.001356       0.000008
# 6861019       o           0.0  9999.0        -0.000254       0.000008
# 6861020       f           0.0  9999.0         0.056320       0.038178
# 6861021       f           0.0  9999.0         0.129776       0.038178
# 6861022       f           0.0  9999.0         0.028866       0.038178
# ...         ...           ...     ...              ...            ...
# 12180216      f           1.0  9999.0         0.775299       0.189467
# 12180217      f           1.0  9999.0         0.790249       0.189467
# 12180218      f           1.0  9999.0         0.753898       0.189467
# 12180219      f           0.0  9999.0         0.046437       0.036786
# 12180220      f           0.0  9999.0         0.043651       0.036786
# 12180221      f           0.0  9999.0         0.010829       0.036786
# 12180222      f           0.0  9999.0         0.028055       0.021026
# 12180223      f           0.0  9999.0         0.044553       0.021026
# 12180224      f           0.0  9999.0         0.021248       0.021026
# 12180225      f           0.0  9999.0         0.027791       0.021026
# 12180226      f           0.0  9999.0         0.056856       0.016656
# 12180227      f           0.0  9999.0         0.035068       0.016656
# 12180228      f           0.0  9999.0        -0.004267       0.016656
# 12180229      f           0.0  9999.0         0.020486       0.016656
# 12180230      m           0.0  9999.0         0.041147       0.082702
# 12180231      m           0.0  9999.0         0.017773       0.082702
# 12180232      m           0.0  9999.0         0.054343       0.082702
# 12180233      m           0.0  9999.0         0.040328       0.082702
# 12180234      f           0.0  9999.0        -0.018199       0.000000
# 12180235      f           0.0  9999.0         0.013201       0.000000
# 12180236      f           0.0  9999.0         0.035516       0.000000
# 12180237      f           0.0  9999.0        -0.006849       0.000000
# 12180238      m           0.0  9999.0         0.113214       0.059606
# 12180239      m           0.0  9999.0         0.095959       0.059606
# 12180240      m           0.0  9999.0         0.028778       0.039300
# 12180241      m           0.0  9999.0         0.046885       0.039300
# 12180242      m           0.0  9999.0         0.067121       0.039300
# 12180243      m           0.0  9999.0         0.887584       0.010273
# 12180244      m           0.0  9999.0         0.847141       0.010273
# 12180245      m           0.0  9999.0         0.846919       0.010273
#
#           adaboost_pred  ada_tuned_pred
# 6860993        0.143697        0.031448
# 6860994        0.081410        0.007819
# 6860995        0.106080       -0.001448
# 6860996        0.100350        0.048923
# 6860997        0.052303        0.015334
# 6860998       -0.013980       -0.008241
# 6860999       -0.008892       -0.021074
# 6861000       -0.018521       -0.032555
# 6861001        0.152182        0.071836
# 6861002        0.207974        0.007770
# 6861003        0.208863       -0.006350
# 6861004        0.164666       -0.009486
# 6861005        0.122420       -0.013586
# 6861006        0.136955        0.029643
# 6861007        0.097337        0.045392
# 6861008        0.182467        0.046089
# 6861009        0.184094        0.052463
# 6861010        0.213695        0.064436
# 6861011        0.181695        0.070583
# 6861012        0.165952       -0.001471
# 6861013        0.213754        0.040841
# 6861014        0.230364        0.016627
# 6861015        0.227162        0.077415
# 6861016        0.037537        0.015999
# 6861017        0.044220       -0.023643
# 6861018        0.035687        0.034047
# 6861019        0.004204        0.031830
# 6861020        0.190423        0.002585
# 6861021        0.176944        0.020098
# 6861022        0.165724        0.050899
# ...                 ...             ...
# 12180216       0.369311        0.257189
# 12180217       0.383687        0.231419
# 12180218       0.381217        0.287045
# 12180219       0.234508        0.062722
# 12180220       0.198379        0.048565
# 12180221       0.198819        0.033949
# 12180222       0.213688        0.060355
# 12180223       0.143612        0.025055
# 12180224       0.201260        0.015147
# 12180225       0.203864        0.019456
# 12180226       0.186255        0.039437
# 12180227       0.223497        0.031312
# 12180228       0.233893        0.041143
# 12180229       0.216747        0.061139
# 12180230       0.237711        0.074755
# 12180231       0.183254        0.031152
# 12180232       0.143850       -0.010327
# 12180233       0.174214        0.060805
# 12180234       0.016844        0.035922
# 12180235      -0.023491        0.008547
# 12180236       0.018688        0.031394
# 12180237       0.025056        0.011321
# 12180238       0.155777        0.029424
# 12180239       0.125080        0.024858
# 12180240       0.168315        0.084143
# 12180241       0.159443        0.043572
# 12180242       0.167671        0.002811
# 12180243       0.105537        0.051700
# 12180244       0.131556       -0.032385
# 12180245       0.147962        0.015648
#
# [5319253 rows x 12 columns]

# %%
test_set = synthetic_df.loc[synthetic_df['grade']==9999.0]
test_set[['countryLabel', 'LoE', 'gender']] = test_set[['countryLabel', 'LoE', 'gender']].fillna('Null')
test_set['countryLabel_bin'] = 0
test_set.loc[test_set['countryLabel']=='United States', 'countryLabel_bin'] = 1
test_set['YoB'] = test_set['YoB'].fillna(df_filled['YoB'].median())
test_set = multi_label_enc.transform(test_set)
test_set.head()
# Out:
# /Users/dvamvou/anaconda3/envs/ds/lib/python3.7/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]
# /Users/dvamvou/anaconda3/envs/ds/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/dvamvou/anaconda3/envs/ds/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /Users/dvamvou/anaconda3/envs/ds/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#          Unnamed: 0  course_id     YoB countryLabel  LoE  gender  \
# 6860993           0         45  1977.0        Haiti    5       1
# 6860994           1         45  1977.0        Haiti    5       1
# 6860995           2         45  1977.0        Haiti    5       1
# 6860996           3         45  1977.0        Haiti    5       1
# 6860997           4         37  1996.0        China    8       2
#
#          nforum_posts   grade  countryLabel_bin
# 6860993           0.0  9999.0                 0
# 6860994           0.0  9999.0                 0
# 6860995           0.0  9999.0                 0
# 6860996           0.0  9999.0                 0
# 6860997           0.0  9999.0                 0

# %%
X_test = test_set[['course_id', 'YoB', 'LoE', 'gender', 'nforum_posts','countryLabel_bin']].values

# %%
dt10_preds = dt_10.predict(X_test)

# %%
noise = np.random.normal(0, 0.025, size=len(dt10_preds))
synthetic_df['grade_dt10_pred'] = synthetic_df['grade']
synthetic_df.loc[synthetic_df['grade_dt10_pred']==9999.0, 'grade_dt10_pred'] = dt10_preds + noise

# %%
corr_bias = df_original_corr - synthetic_df['grade_dt10_pred'].corr(synthetic_df['nforum_posts'], method='pearson')
mean_bias = df_original_cleaned['grade'].mean() - synthetic_df['grade_dt10_pred'].mean()
print(f'Bias in mean grade for imputation with predicted value from decision tree is {np.abs(mean_bias)}')
print(f'Bias in correlation between grade and nforum_posts for imputation with predicted value from decision tree is {np.abs(corr_bias)}')
# Out:
# Bias in mean grade for imputation with predicted value from decision tree is 0.03872050770831121
# Bias in correlation between grade and nforum_posts for imputation with predicted value from decision tree is 0.05783441034780906

# %% [markdown]
# ## Imputation with Random Forest predicted grade

# %%
rf = ensemble.RandomForestRegressor(n_estimators = 50, max_depth = 10, max_features = 5)
rf.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#                       max_features=5, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=50,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rf_preds = rf.predict(X_test)
noise = np.random.normal(0, 0.025, size=len(rf_preds))


synthetic_df['grade_rf_pred'] = synthetic_df['grade']
synthetic_df.loc[synthetic_df['grade_rf_pred']==9999.0, 'grade_rf_pred'] = rf_preds + noise

# %%
corr_bias = df_original_corr - synthetic_df['grade_rf_pred'].corr(synthetic_df['nforum_posts'], method='pearson')
mean_bias = df_original_cleaned['grade'].mean() - synthetic_df['grade_rf_pred'].mean()
print(f'Bias in mean grade for imputation with predicted value from random forest is {np.abs(mean_bias)}')
print(f'Bias in correlation between grade and nforum_posts for imputation with predicted value from random forest is {np.abs(corr_bias)}')
# Out:
# Bias in mean grade for imputation with predicted value from random forest is 0.03436038547425271
# Bias in correlation between grade and nforum_posts for imputation with predicted value from random forest is 0.08591764273627661

# %% [markdown]
# ## Imputation with Bagging predicted grade

# %%
bagging = ensemble.RandomForestRegressor(n_estimators = 50, max_depth = 10, max_features = X.shape[1])
bagging.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#                       max_features=6, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=50,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
bagging_preds = bagging.predict(X_test)
noise = np.random.normal(0, 0.025, size=len(bagging_preds))

synthetic_df['grade_bagging_pred'] = synthetic_df['grade']
synthetic_df.loc[synthetic_df['grade_bagging_pred']==9999.0, 'grade_bagging_pred'] = bagging_preds + noise

# %%
corr_bias = df_original_corr - synthetic_df['grade_bagging_pred'].corr(synthetic_df['nforum_posts'], method='pearson')
mean_bias = df_original_cleaned['grade'].mean() - synthetic_df['grade_bagging_pred'].mean()
print(f'Bias in mean grade for imputation with predicted value from bagging is {np.abs(mean_bias)}')
print(f'Bias in correlation between grade and nforum_posts for imputation with predicted value from bagging is {np.abs(corr_bias)}')
# Out:
# Bias in mean grade for imputation with predicted value from bagging is 0.038374982646014945
# Bias in correlation between grade and nforum_posts for imputation with predicted value from bagging is 0.06213311574046215

# %% [markdown]
# ## Imputation with AdaBoost predicted grade

# %%
adaboost = ensemble.AdaBoostRegressor(n_estimators = 500, learning_rate = 0.1)
adaboost.fit(X, y)
# Out:
# AdaBoostRegressor(base_estimator=None, learning_rate=0.1, loss='linear',
#                   n_estimators=500, random_state=None)

# %%
adaboost_preds = adaboost.predict(X_test)
noise = np.random.normal(0, 0.025, size=len(adaboost_preds))

synthetic_df['adaboost_pred'] = synthetic_df['grade']
synthetic_df.loc[synthetic_df['adaboost_pred']==9999.0, 'adaboost_pred'] = adaboost_preds + noise

# %%
corr_bias = df_original_corr - synthetic_df['adaboost_pred'].corr(synthetic_df['nforum_posts'], method='pearson')
mean_bias = df_original_cleaned['grade'].mean() - synthetic_df['adaboost_pred'].mean()
print(f'Bias in mean grade for imputation with predicted value from adaboost is {np.abs(mean_bias)}')
print(f'Bias in correlation between grade and nforum_posts for imputation with predicted value from adaboost is {np.abs(corr_bias)}')
# Out:
# Bias in mean grade for imputation with predicted value from adaboost is 0.07210078917198387
# Bias in correlation between grade and nforum_posts for imputation with predicted value from adaboost is 0.05477595511579658
